# %% [markdown]
# <h1>Autoencoder - Keras</h1>

# %% [markdown]
# <h2>Autoencoder Simples</h2>

# %%
import keras
from keras import layers
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
from keras import regularizers
from keras import layers
from keras.callbacks import TensorBoard
from keras import backend as K

# %%
# This is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# This is our input image
input_img = keras.Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

# This model maps an input to its reconstruction
autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 10s 9ms/step - loss: 0.3814 - val_loss: 0.1891
# Epoch 2/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1802 - val_loss: 0.1550
# Epoch 3/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1498 - val_loss: 0.1335
# Epoch 4/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1310 - val_loss: 0.1207
# Epoch 5/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1199 - val_loss: 0.1124
# Epoch 6/50
# 235/235 [==============================] - 1s 6ms/step - loss: 0.1118 - val_loss: 0.1067
# Epoch 7/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1069 - val_loss: 0.1024
# Epoch 8/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1027 - val_loss: 0.0993
# Epoch 9/50
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0999 - val_loss: 0.0970
# Epoch 10/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0978 - val_loss: 0.0954
# Epoch 11/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0964 - val_loss: 0.0944
# Epoch 12/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0955 - val_loss: 0.0937
# Epoch 13/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0948 - val_loss: 0.0932
# Epoch 14/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0945 - val_loss: 0.0929
# Epoch 15/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0941 - val_loss: 0.0927
# Epoch 16/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0941 - val_loss: 0.0925
# Epoch 17/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0937 - val_loss: 0.0923
# Epoch 18/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0937 - val_loss: 0.0923
# Epoch 19/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 20/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0932 - val_loss: 0.0922
# Epoch 21/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0932 - val_loss: 0.0921
# Epoch 22/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 23/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0933 - val_loss: 0.0919
# Epoch 24/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 25/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0929 - val_loss: 0.0919
# Epoch 26/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 27/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 28/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 29/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 30/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 31/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 32/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 33/50
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 34/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0926 - val_loss: 0.0917
# Epoch 35/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 36/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 37/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0928 - val_loss: 0.0915
# Epoch 38/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 39/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 40/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 41/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 42/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0928 - val_loss: 0.0914
# Epoch 43/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0926 - val_loss: 0.0915
# Epoch 44/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0928 - val_loss: 0.0915
# Epoch 45/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0924 - val_loss: 0.0915
# Epoch 46/50
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0927 - val_loss: 0.0914
# Epoch 47/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0914
# Epoch 48/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0924 - val_loss: 0.0915
# Epoch 49/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0925 - val_loss: 0.0915
# Epoch 50/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0923 - val_loss: 0.0914

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# <h2>Sparsity Constraint</h2>

# %%
encoding_dim = 32

input_img = keras.Input(shape=(784,))
# Add a Dense layer with a L1 activity regularizer
encoded = layers.Dense(encoding_dim, activation='relu',
                activity_regularizer=regularizers.l1(10e-5))(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)

# %%
# This model maps an input to its encoded representation
encoder = keras.Model(input_img, encoded)

# %%
# This is our encoded (32-dimensional) input
encoded_input = keras.Input(shape=(encoding_dim,))
# Retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# Create the decoder model
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 3s 9ms/step - loss: 0.3944 - val_loss: 0.1979
# Epoch 2/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1887 - val_loss: 0.1637
# Epoch 3/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1594 - val_loss: 0.1442
# Epoch 4/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1411 - val_loss: 0.1299
# Epoch 5/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1289 - val_loss: 0.1222
# Epoch 6/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1219 - val_loss: 0.1172
# Epoch 7/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1169 - val_loss: 0.1128
# Epoch 8/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1131 - val_loss: 0.1101
# Epoch 9/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1107 - val_loss: 0.1080
# Epoch 10/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1089 - val_loss: 0.1066
# Epoch 11/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1074 - val_loss: 0.1057
# Epoch 12/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1065 - val_loss: 0.1049
# Epoch 13/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1059 - val_loss: 0.1042
# Epoch 14/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1053 - val_loss: 0.1037
# Epoch 15/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1049 - val_loss: 0.1033
# Epoch 16/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1044 - val_loss: 0.1029
# Epoch 17/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1040 - val_loss: 0.1025
# Epoch 18/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1037 - val_loss: 0.1022
# Epoch 19/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1032 - val_loss: 0.1020
# Epoch 20/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1030 - val_loss: 0.1017
# Epoch 21/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1028 - val_loss: 0.1014
# Epoch 22/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1028 - val_loss: 0.1012
# Epoch 23/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1023 - val_loss: 0.1010
# Epoch 24/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1018 - val_loss: 0.1008
# Epoch 25/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1018 - val_loss: 0.1006
# Epoch 26/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1016 - val_loss: 0.1004
# Epoch 27/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1013 - val_loss: 0.1002
# Epoch 28/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1014 - val_loss: 0.1001
# Epoch 29/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1011 - val_loss: 0.1000
# Epoch 30/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1009 - val_loss: 0.0998
# Epoch 31/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1007 - val_loss: 0.0997
# Epoch 32/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1008 - val_loss: 0.0995
# Epoch 33/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.1005 - val_loss: 0.0995
# Epoch 34/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1005 - val_loss: 0.0993
# Epoch 35/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1002 - val_loss: 0.0991
# Epoch 36/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1003 - val_loss: 0.0990
# Epoch 37/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1000 - val_loss: 0.0990
# Epoch 38/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0998 - val_loss: 0.0988
# Epoch 39/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0999 - val_loss: 0.0988
# Epoch 40/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0997 - val_loss: 0.0986
# Epoch 41/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0998 - val_loss: 0.0985
# Epoch 42/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0996 - val_loss: 0.0985
# Epoch 43/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0995 - val_loss: 0.0984
# Epoch 44/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0995 - val_loss: 0.0983
# Epoch 45/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0996 - val_loss: 0.0982
# Epoch 46/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0991 - val_loss: 0.0983
# Epoch 47/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0991 - val_loss: 0.0982
# Epoch 48/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0993 - val_loss: 0.0980
# Epoch 49/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0992 - val_loss: 0.0979
# Epoch 50/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0990 - val_loss: 0.0979
# Epoch 51/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0988 - val_loss: 0.0978
# Epoch 52/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0986 - val_loss: 0.0977
# Epoch 53/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0987 - val_loss: 0.0977
# Epoch 54/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0987 - val_loss: 0.0976
# Epoch 55/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0987 - val_loss: 0.0976
# Epoch 56/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0987 - val_loss: 0.0975
# Epoch 57/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0984 - val_loss: 0.0975
# Epoch 58/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0986 - val_loss: 0.0974
# Epoch 59/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0984 - val_loss: 0.0973
# Epoch 60/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0983 - val_loss: 0.0973
# Epoch 61/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0984 - val_loss: 0.0972
# Epoch 62/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0983 - val_loss: 0.0972
# Epoch 63/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0982 - val_loss: 0.0971
# Epoch 64/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0983 - val_loss: 0.0971
# Epoch 65/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0980 - val_loss: 0.0971
# Epoch 66/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0981 - val_loss: 0.0970
# Epoch 67/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0981 - val_loss: 0.0969
# Epoch 68/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0980 - val_loss: 0.0969
# Epoch 69/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0979 - val_loss: 0.0969
# Epoch 70/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0978 - val_loss: 0.0969
# Epoch 71/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0981 - val_loss: 0.0968
# Epoch 72/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0980 - val_loss: 0.0968
# Epoch 73/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0980 - val_loss: 0.0967
# Epoch 74/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0979 - val_loss: 0.0968
# Epoch 75/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0977 - val_loss: 0.0966
# Epoch 76/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0975 - val_loss: 0.0966
# Epoch 77/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0973 - val_loss: 0.0966
# Epoch 78/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0976 - val_loss: 0.0965
# Epoch 79/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0973 - val_loss: 0.0965
# Epoch 80/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0976 - val_loss: 0.0965
# Epoch 81/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0974 - val_loss: 0.0963
# Epoch 82/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0973 - val_loss: 0.0964
# Epoch 83/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0974 - val_loss: 0.0964
# Epoch 84/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0973 - val_loss: 0.0963
# Epoch 85/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0974 - val_loss: 0.0964
# Epoch 86/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0974 - val_loss: 0.0962
# Epoch 87/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0973 - val_loss: 0.0963
# Epoch 88/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0973 - val_loss: 0.0961
# Epoch 89/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0970 - val_loss: 0.0961
# Epoch 90/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0972 - val_loss: 0.0962
# Epoch 91/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0971 - val_loss: 0.0961
# Epoch 92/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0974 - val_loss: 0.0961
# Epoch 93/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0970 - val_loss: 0.0960
# Epoch 94/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0970 - val_loss: 0.0960
# Epoch 95/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0967 - val_loss: 0.0959
# Epoch 96/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0970 - val_loss: 0.0960
# Epoch 97/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0969 - val_loss: 0.0959
# Epoch 98/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0970 - val_loss: 0.0960
# Epoch 99/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0968 - val_loss: 0.0959
# Epoch 100/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0968 - val_loss: 0.0958

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# <h2>Deep Autoencoder</h2>

# %%
(x_train, _), (x_test, _) = mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# %%
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 3s 11ms/step - loss: 0.3294 - val_loss: 0.1683
# Epoch 2/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1586 - val_loss: 0.1349
# Epoch 3/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1328 - val_loss: 0.1236
# Epoch 4/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1225 - val_loss: 0.1154
# Epoch 5/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1157 - val_loss: 0.1107
# Epoch 6/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1110 - val_loss: 0.1068
# Epoch 7/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1078 - val_loss: 0.1052
# Epoch 8/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1051 - val_loss: 0.1032
# Epoch 9/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1036 - val_loss: 0.1012
# Epoch 10/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1020 - val_loss: 0.0997
# Epoch 11/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.1006 - val_loss: 0.0987
# Epoch 12/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0994 - val_loss: 0.0971
# Epoch 13/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0980 - val_loss: 0.0964
# Epoch 14/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0970 - val_loss: 0.0953
# Epoch 15/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0961 - val_loss: 0.0940
# Epoch 16/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0948 - val_loss: 0.0935
# Epoch 17/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0942 - val_loss: 0.0931
# Epoch 18/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0935 - val_loss: 0.0925
# Epoch 19/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0928 - val_loss: 0.0914
# Epoch 20/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0920 - val_loss: 0.0912
# Epoch 21/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0915 - val_loss: 0.0905
# Epoch 22/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0911 - val_loss: 0.0901
# Epoch 23/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0907 - val_loss: 0.0898
# Epoch 24/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0901 - val_loss: 0.0891
# Epoch 25/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0897 - val_loss: 0.0890
# Epoch 26/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0894 - val_loss: 0.0884
# Epoch 27/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0890 - val_loss: 0.0880
# Epoch 28/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0887 - val_loss: 0.0878
# Epoch 29/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0885 - val_loss: 0.0875
# Epoch 30/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0879 - val_loss: 0.0874
# Epoch 31/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0876 - val_loss: 0.0874
# Epoch 32/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0876 - val_loss: 0.0867
# Epoch 33/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0870 - val_loss: 0.0864
# Epoch 34/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0869 - val_loss: 0.0863
# Epoch 35/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0865 - val_loss: 0.0860
# Epoch 36/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0862 - val_loss: 0.0858
# Epoch 37/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0862 - val_loss: 0.0855
# Epoch 38/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0861 - val_loss: 0.0854
# Epoch 39/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0859 - val_loss: 0.0854
# Epoch 40/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0857 - val_loss: 0.0850
# Epoch 41/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0856 - val_loss: 0.0851
# Epoch 42/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0854 - val_loss: 0.0851
# Epoch 43/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0853 - val_loss: 0.0847
# Epoch 44/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0851 - val_loss: 0.0847
# Epoch 45/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0850 - val_loss: 0.0847
# Epoch 46/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0848 - val_loss: 0.0842
# Epoch 47/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0847 - val_loss: 0.0843
# Epoch 48/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0846 - val_loss: 0.0845
# Epoch 49/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0845 - val_loss: 0.0840
# Epoch 50/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0842 - val_loss: 0.0838
# Epoch 51/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0842 - val_loss: 0.0838
# Epoch 52/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0840 - val_loss: 0.0839
# Epoch 53/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0839 - val_loss: 0.0835
# Epoch 54/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0840 - val_loss: 0.0836
# Epoch 55/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0838 - val_loss: 0.0835
# Epoch 56/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0837 - val_loss: 0.0835
# Epoch 57/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0838 - val_loss: 0.0837
# Epoch 58/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0838 - val_loss: 0.0835
# Epoch 59/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0836 - val_loss: 0.0835
# Epoch 60/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0835 - val_loss: 0.0830
# Epoch 61/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0835 - val_loss: 0.0830
# Epoch 62/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0833 - val_loss: 0.0832
# Epoch 63/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0831 - val_loss: 0.0831
# Epoch 64/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0832 - val_loss: 0.0831
# Epoch 65/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0833 - val_loss: 0.0827
# Epoch 66/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0831 - val_loss: 0.0828
# Epoch 67/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0830 - val_loss: 0.0830
# Epoch 68/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0830 - val_loss: 0.0826
# Epoch 69/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0827 - val_loss: 0.0827
# Epoch 70/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0827 - val_loss: 0.0828
# Epoch 71/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0829 - val_loss: 0.0827
# Epoch 72/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0828 - val_loss: 0.0826
# Epoch 73/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0827 - val_loss: 0.0825
# Epoch 74/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0828 - val_loss: 0.0825
# Epoch 75/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0825 - val_loss: 0.0825
# Epoch 76/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0826 - val_loss: 0.0824
# Epoch 77/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0824 - val_loss: 0.0823
# Epoch 78/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0825 - val_loss: 0.0824
# Epoch 79/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0823 - val_loss: 0.0822
# Epoch 80/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0823 - val_loss: 0.0824
# Epoch 81/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0822 - val_loss: 0.0825
# Epoch 82/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0823 - val_loss: 0.0823
# Epoch 83/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0821 - val_loss: 0.0823
# Epoch 84/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0825 - val_loss: 0.0821
# Epoch 85/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0820 - val_loss: 0.0822
# Epoch 86/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0822 - val_loss: 0.0822
# Epoch 87/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0821 - val_loss: 0.0821
# Epoch 88/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0822 - val_loss: 0.0819
# Epoch 89/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0822 - val_loss: 0.0820
# Epoch 90/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0821 - val_loss: 0.0821
# Epoch 91/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0821 - val_loss: 0.0820
# Epoch 92/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0820 - val_loss: 0.0821
# Epoch 93/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0821 - val_loss: 0.0818
# Epoch 94/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0818 - val_loss: 0.0819
# Epoch 95/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0818 - val_loss: 0.0819
# Epoch 96/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0818 - val_loss: 0.0816
# Epoch 97/100
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0818 - val_loss: 0.0817
# Epoch 98/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0818 - val_loss: 0.0819
# Epoch 99/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0819 - val_loss: 0.0817
# Epoch 100/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0817 - val_loss: 0.0819

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# <h2>Convolutional autoencoder</h2>

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
# Rodar este comando no terminal
# tensorboard --logdir=/tmp/autoencoder

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 43s 88ms/step - loss: 0.3095 - val_loss: 0.1520
# Epoch 2/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.1463 - val_loss: 0.1313
# Epoch 3/50
# 469/469 [==============================] - 39s 83ms/step - loss: 0.1300 - val_loss: 0.1223
# Epoch 4/50
# 469/469 [==============================] - 40s 85ms/step - loss: 0.1220 - val_loss: 0.1169
# Epoch 5/50
# 469/469 [==============================] - 39s 83ms/step - loss: 0.1172 - val_loss: 0.1130
# Epoch 6/50
# 469/469 [==============================] - 38s 82ms/step - loss: 0.1136 - val_loss: 0.1100
# Epoch 7/50
# 469/469 [==============================] - 41s 88ms/step - loss: 0.1105 - val_loss: 0.1088
# Epoch 8/50
# 469/469 [==============================] - 41s 87ms/step - loss: 0.1084 - val_loss: 0.1059
# Epoch 9/50
# 469/469 [==============================] - 39s 82ms/step - loss: 0.1070 - val_loss: 0.1045
# Epoch 10/50
# 469/469 [==============================] - 39s 84ms/step - loss: 0.1054 - val_loss: 0.1032
# Epoch 11/50
# Epoch 41/50
# 469/469 [==============================] - 39s 84ms/step - loss: 0.0939 - val_loss: 0.0927
# Epoch 42/50
# 469/469 [==============================] - 39s 82ms/step - loss: 0.0937 - val_loss: 0.0927
# Epoch 43/50
# 469/469 [==============================] - 40s 85ms/step - loss: 0.0935 - val_loss: 0.0926
# Epoch 44/50
# 469/469 [==============================] - 40s 85ms/step - loss: 0.0937 - val_loss: 0.0924
# Epoch 45/50
# 469/469 [==============================] - 39s 82ms/step - loss: 0.0934 - val_loss: 0.0922
# Epoch 46/50
# 469/469 [==============================] - 40s 85ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 47/50
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0931 - val_loss: 0.0925
# Epoch 48/50
# 469/469 [==============================] - 38s 82ms/step - loss: 0.0932 - val_loss: 0.0920
# Epoch 49/50
# 469/469 [==============================] - 40s 84ms/step - loss: 0.0931 - val_loss: 0.0923
# Epoch 50/50
# 469/469 [==============================] - 40s 86ms/step - loss: 0.0929 - val_loss: 0.0917

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
encoder = keras.Model(input_img, encoded)
encoded_imgs = encoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 8))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(encoded_imgs[i].reshape((4, 4 * 8)).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# <h2>Image Denoising</h2>

# %%
(x_train, _), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

noise_factor = 0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(1, n + 1):
    ax = plt.subplot(1, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = keras.Input(shape=(28, 28, 1))

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train_noisy, x_train,
                epochs=100,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/tb', histogram_freq=0, write_graph=False)])
# Out:
# Epoch 1/100
# 469/469 [==============================] - 71s 150ms/step - loss: 0.2467 - val_loss: 0.1136
# Epoch 2/100
# 469/469 [==============================] - 73s 155ms/step - loss: 0.1127 - val_loss: 0.1067
# Epoch 3/100
# 469/469 [==============================] - 75s 160ms/step - loss: 0.1067 - val_loss: 0.1034
# Epoch 4/100
# 469/469 [==============================] - 71s 150ms/step - loss: 0.1041 - val_loss: 0.1014
# Epoch 5/100
# 469/469 [==============================] - 70s 149ms/step - loss: 0.1023 - val_loss: 0.1006
# Epoch 6/100
# 469/469 [==============================] - 69s 148ms/step - loss: 0.1006 - val_loss: 0.0993
# Epoch 7/100
# 469/469 [==============================] - 71s 151ms/step - loss: 0.0995 - val_loss: 0.0983
# Epoch 8/100
# 469/469 [==============================] - 69s 147ms/step - loss: 0.0989 - val_loss: 0.0981
# Epoch 9/100
# 469/469 [==============================] - 70s 150ms/step - loss: 0.0986 - val_loss: 0.0974
# Epoch 10/100
# 469/469 [==============================] - 70s 149ms/step - loss: 0.0976 - val_loss: 0.0967
# Epoch 11/100
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0975 - val_loss: 0.0964
# Epoch 12/100
# 469/469 [==============================] - 71s 151ms/step - loss: 0.0970 - val_loss: 0.0963
# Epoch 13/100
# 469/469 [==============================] - 68s 146ms/step - loss: 0.0968 - val_loss: 0.0959
# Epoch 14/100
# 469/469 [==============================] - 70s 150ms/step - loss: 0.0964 - val_loss: 0.0955
ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 78/100
# 469/469 [==============================] - 70s 150ms/step - loss: 0.0932 - val_loss: 0.0938
# Epoch 79/100
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 80/100
# 469/469 [==============================] - 70s 148ms/step - loss: 0.0931 - val_loss: 0.0932
# Epoch 81/100
# 469/469 [==============================] - 70s 149ms/step - loss: 0.0930 - val_loss: 0.0932
# Epoch 82/100
# 469/469 [==============================] - 69s 147ms/step - loss: 0.0934 - val_loss: 0.0932
# Epoch 83/100
# 469/469 [==============================] - 71s 151ms/step - loss: 0.0931 - val_loss: 0.0931
# Epoch 84/100
# 469/469 [==============================] - 69s 147ms/step - loss: 0.0932 - val_loss: 0.0931
# Epoch 85/100
# 469/469 [==============================] - 70s 148ms/step - loss: 0.0933 - val_loss: 0.0933
# Epoch 86/100
# 469/469 [==============================] - 70s 149ms/step - loss: 0.0930 - val_loss: 0.0931
# Epoch 87/100
# 469/469 [==============================] - 69s 148ms/step - loss: 0.0930 - val_loss: 0.0932
# Epoch 88/100
# 469/469 [==============================] - 76s 162ms/step - loss: 0.0930 - val_loss: 0.0932
# Epoch 89/100
# 469/469 [==============================] - 75s 161ms/step - loss: 0.0931 - val_loss: 0.0931
# Epoch 90/100
# 469/469 [==============================] - 78s 165ms/step - loss: 0.0930 - val_loss: 0.0932
# Epoch 91/100
# 469/469 [==============================] - 73s 155ms/step - loss: 0.0931 - val_loss: 0.0931
# Epoch 92/100
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0932 - val_loss: 0.0930
# Epoch 93/100
# 469/469 [==============================] - 73s 156ms/step - loss: 0.0931 - val_loss: 0.0931
# Epoch 94/100
# 469/469 [==============================] - 71s 151ms/step - loss: 0.0935 - val_loss: 0.0931
# Epoch 95/100
# 469/469 [==============================] - 74s 158ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 96/100
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0932 - val_loss: 0.0932
# Epoch 97/100
# 469/469 [==============================] - 72s 154ms/step - loss: 0.0931 - val_loss: 0.0931
# Epoch 98/100
# 469/469 [==============================] - 72s 154ms/step - loss: 0.0930 - val_loss: 0.0931
# Epoch 99/100
# 469/469 [==============================] - 72s 153ms/step - loss: 0.0933 - val_loss: 0.0931
# Epoch 100/100
# 469/469 [==============================] - 74s 157ms/step - loss: 0.0931 - val_loss: 0.0930

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# <h2>Variational Autoencoder</h2>

# %%
original_dim = 28 * 28
intermediate_dim = 64
latent_dim = 2

inputs = keras.Input(shape=(original_dim,))
h = layers.Dense(intermediate_dim, activation='relu')(inputs)
z_mean = layers.Dense(latent_dim)(h)
z_log_sigma = layers.Dense(latent_dim)(h)

# %%
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim),
                              mean=0., stddev=0.1)
    return z_mean + K.exp(z_log_sigma) * epsilon

z = layers.Lambda(sampling)([z_mean, z_log_sigma])

# %%
# Create encoder
encoder = keras.Model(inputs, [z_mean, z_log_sigma, z], name='encoder')

# Create decoder
latent_inputs = keras.Input(shape=(latent_dim,), name='z_sampling')
x = layers.Dense(intermediate_dim, activation='relu')(latent_inputs)
outputs = layers.Dense(original_dim, activation='sigmoid')(x)
decoder = keras.Model(latent_inputs, outputs, name='decoder')

# instantiate VAE model
outputs = decoder(encoder(inputs)[2])
vae = keras.Model(inputs, outputs, name='vae_mlp')

# %%
reconstruction_loss = keras.losses.binary_crossentropy(inputs, outputs)
reconstruction_loss *= original_dim
kl_loss = 1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma)
kl_loss = K.sum(kl_loss, axis=-1)
kl_loss *= -0.5
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

vae.fit(x_train, x_train,
        epochs=100,
        batch_size=32,
        validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 221.2598 - val_loss: 167.5398
# Epoch 2/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 166.3906 - val_loss: 162.9651
# Epoch 3/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 161.9222 - val_loss: 160.5930
# Epoch 4/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 159.3688 - val_loss: 158.8813
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 158.4135 - val_loss: 157.6806
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 157.0910 - val_loss: 156.7069
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 156.2501 - val_loss: 155.8717
# Epoch 8/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 155.3611 - val_loss: 155.3221
# Epoch 9/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 154.0955 - val_loss: 154.4249
# Epoch 10/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 153.6889 - val_loss: 153.8267
# Epoch 11/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 152.8943 - val_loss: 153.4002
# Epoch 12/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 152.3873 - val_loss: 152.8071
# Epoch 13/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 151.8147 - val_loss: 152.2680
# Epoch 14/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 151.4177 - val_loss: 152.3275
# Epoch 15/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 150.8947 - val_loss: 151.3352
# Epoch 16/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 150.5499 - val_loss: 151.0687
# Epoch 17/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 149.9022 - val_loss: 150.9557
# Epoch 18/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.8007 - val_loss: 150.2261
# Epoch 19/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 149.9705 - val_loss: 149.9699
# Epoch 20/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 149.1589 - val_loss: 149.7881
# Epoch 21/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 149.0258 - val_loss: 149.6342
# Epoch 22/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.9574 - val_loss: 149.3444
# Epoch 23/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.6246 - val_loss: 149.2402
# Epoch 24/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 148.1545 - val_loss: 149.2334
# Epoch 25/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.8643 - val_loss: 148.8216
# Epoch 26/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 147.6881 - val_loss: 148.4756
# Epoch 27/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 147.7975 - val_loss: 148.4214
# Epoch 28/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.5760 - val_loss: 148.4897
# Epoch 29/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.3066 - val_loss: 148.2908
# Epoch 30/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.8994 - val_loss: 148.3988
# Epoch 31/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.0552 - val_loss: 148.1020
# Epoch 32/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 147.0589 - val_loss: 148.1462
# Epoch 33/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.7172 - val_loss: 148.1709
# Epoch 34/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.9560 - val_loss: 147.9826
# Epoch 35/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 146.6700 - val_loss: 147.7426
# Epoch 36/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.9243 - val_loss: 147.5734
# Epoch 37/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.5161 - val_loss: 147.7011
# Epoch 38/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 146.3494 - val_loss: 147.7642
# Epoch 39/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.0068 - val_loss: 147.3194
# Epoch 40/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 146.2656 - val_loss: 147.3288
# Epoch 41/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.9966 - val_loss: 147.4023
# Epoch 42/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.6985 - val_loss: 147.1568
# Epoch 43/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.9596 - val_loss: 147.3958
# Epoch 44/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.7120 - val_loss: 147.0643
# Epoch 45/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.7522 - val_loss: 146.9949
# Epoch 46/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.5805 - val_loss: 147.0779
# Epoch 47/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.8210 - val_loss: 146.8952
# Epoch 48/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.3398 - val_loss: 147.0354
# Epoch 49/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.1484 - val_loss: 147.0891
# Epoch 50/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.2199 - val_loss: 146.8396
# Epoch 51/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.0205 - val_loss: 146.7189
# Epoch 52/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 145.1156 - val_loss: 146.6503
# Epoch 53/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.9380 - val_loss: 146.8676
# Epoch 54/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.8381 - val_loss: 146.8694
# Epoch 55/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 145.1382 - val_loss: 146.6841
# Epoch 56/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 145.0141 - val_loss: 146.6776
# Epoch 57/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.7007 - val_loss: 146.4159
# Epoch 58/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.8929 - val_loss: 146.5144
# Epoch 59/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.5968 - val_loss: 146.2748
# Epoch 60/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.5923 - val_loss: 146.3291
# Epoch 61/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 144.6939 - val_loss: 146.4929
# Epoch 62/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.5299 - val_loss: 146.2646
# Epoch 63/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.6564 - val_loss: 146.2403
# Epoch 64/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.1175 - val_loss: 146.1875
# Epoch 65/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.2420 - val_loss: 146.0710
# Epoch 66/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.3052 - val_loss: 146.1058
# Epoch 67/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.4084 - val_loss: 146.3668
# Epoch 68/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.1114 - val_loss: 146.3386
# Epoch 69/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 144.3021 - val_loss: 145.8609
# Epoch 70/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.0909 - val_loss: 145.8968
# Epoch 71/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.3303 - val_loss: 146.1187
# Epoch 72/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.5991 - val_loss: 146.1714
# Epoch 73/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 143.7398 - val_loss: 146.1154
# Epoch 74/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.5919 - val_loss: 145.8475
# Epoch 75/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.7898 - val_loss: 145.7362
# Epoch 76/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 144.1760 - val_loss: 145.8257
# Epoch 77/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.7336 - val_loss: 145.8457
# Epoch 78/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 143.5647 - val_loss: 145.7867
# Epoch 79/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.6652 - val_loss: 146.3158
# Epoch 80/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.3996 - val_loss: 146.1302
# Epoch 81/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.4923 - val_loss: 145.8881
# Epoch 82/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 143.3143 - val_loss: 145.7675
# Epoch 83/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.6240 - val_loss: 145.6071
# Epoch 84/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 143.5865 - val_loss: 145.8696
# Epoch 85/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 143.3304 - val_loss: 145.7216
# Epoch 86/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.3735 - val_loss: 145.6055
# Epoch 87/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.2426 - val_loss: 145.6198
# Epoch 88/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.1699 - val_loss: 145.2932
# Epoch 89/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.3749 - val_loss: 145.4363
# Epoch 90/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 143.5013 - val_loss: 145.6622
# Epoch 91/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.1972 - val_loss: 145.5680
# Epoch 92/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 142.7614 - val_loss: 145.5413
# Epoch 93/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 142.9361 - val_loss: 145.2927
# Epoch 94/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.2812 - val_loss: 145.6150
# Epoch 95/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 142.9724 - val_loss: 145.3814
# Epoch 96/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 142.9767 - val_loss: 145.6270
# Epoch 97/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 142.9646 - val_loss: 145.2409
# Epoch 98/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 143.0728 - val_loss: 145.4388
# Epoch 99/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 143.1005 - val_loss: 145.2126
# Epoch 100/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 142.7601 - val_loss: 145.3391

# %%
x_test_encoded = encoder.predict(x_test, batch_size=32)
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[0][:, 0], x_test_encoded[0][:, 1], c=y_test, cmap='gist_rainbow')
plt.colorbar()
plt.show()

# %%
# Display a 2D manifold of the digits
n = 15  # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))
# We will sample n points within [-15, 15] standard deviations
grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
