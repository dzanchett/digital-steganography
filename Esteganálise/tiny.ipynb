# %% [markdown]
# <h3>Importação de Bibliotecas</h3>

# %%
import os

# %% [markdown]
# <h3>Clona o repositório da ferramenta de esteganálise</h3>

# %%
# !git clone https://github.com/b3dk7/StegExpose.git
# Out:
# Cloning into 'StegExpose'...
# remote: Enumerating objects: 314, done.
# remote: Total 314 (delta 0), reused 0 (delta 0), pack-reused 314
# Receiving objects: 100% (314/314), 38.31 MiB | 33.19 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %% [markdown]
# <h3>Análisa o diretório de imagens contendo esteganografia</h3>

# %%
# !cd StegExpose/ && java -jar StegExpose.jar ../dataset_encoder
# Out:
# 53.png is suspicious. Approximate amount of hidden data is 1181 bytes.
# 962.png is suspicious. Approximate amount of hidden data is 766 bytes.
# 394.png is suspicious. Approximate amount of hidden data is 1829 bytes.
# 890.png is suspicious. Approximate amount of hidden data is 1754 bytes.
# 172.png is suspicious. Approximate amount of hidden data is 998 bytes.
# 280.png is suspicious. Approximate amount of hidden data is 1227 bytes.
# 51.png is suspicious. Approximate amount of hidden data is 1134 bytes.
# 804.png is suspicious. Approximate amount of hidden data is 946 bytes.
# 974.png is suspicious. Approximate amount of hidden data is 699 bytes.
# 672.png is suspicious. Approximate amount of hidden data is 726 bytes.
# 59.png is suspicious. Approximate amount of hidden data is 1568 bytes.
# 38.png is suspicious. Approximate amount of hidden data is 1698 bytes.
# 531.png is suspicious. Approximate amount of hidden data is 1137 bytes.
# ...

# %%
# !cd StegExpose/ && java -jar StegExpose.jar ../dataset_dct
# Out:
# 03976.jpeg is suspicious. Approximate amount of hidden data is 1270 bytes.
# 00451.jpeg is suspicious. Approximate amount of hidden data is 326 bytes.
# 03172.jpeg is suspicious. Approximate amount of hidden data is 365 bytes.
# 03528.jpeg is suspicious. Approximate amount of hidden data is 266 bytes.
# 03135.jpeg is suspicious. Approximate amount of hidden data is 344 bytes.
# 01115.jpeg is suspicious. Approximate amount of hidden data is 512 bytes.
# 04362.jpeg is suspicious. Approximate amount of hidden data is 1210 bytes.
# 01482.jpeg is suspicious. Approximate amount of hidden data is 1127 bytes.
# 00946.jpeg is suspicious. Approximate amount of hidden data is 350 bytes.
# 00463.jpeg is suspicious. Approximate amount of hidden data is 626 bytes.
# 01540.jpeg is suspicious. Approximate amount of hidden data is 814 bytes.
# 01029.jpeg is suspicious. Approximate amount of hidden data is 428 bytes.
# 00689.jpeg is suspicious. Approximate amount of hidden data is 529 bytes.
# ...

# %%
# !cd StegExpose/ && java -jar StegExpose.jar ../dataset_lsb_grayscale
# Out:
# 1827.bmp is suspicious. Approximate amount of hidden data is 429 bytes.
# 2002.bmp is suspicious. Approximate amount of hidden data is 501 bytes.
# 4298.bmp is suspicious. Approximate amount of hidden data is 1166 bytes.
# 162.bmp is suspicious. Approximate amount of hidden data is 1390 bytes.
# 3827.bmp is suspicious. Approximate amount of hidden data is 769 bytes.
# 3815.bmp is suspicious. Approximate amount of hidden data is 672 bytes.
# 2202.bmp is suspicious. Approximate amount of hidden data is 699 bytes.
# 2047.bmp is suspicious. Approximate amount of hidden data is 787 bytes.
# 4583.bmp is suspicious. Approximate amount of hidden data is 430 bytes.
# 1455.bmp is suspicious. Approximate amount of hidden data is 625 bytes.
# 1499.bmp is suspicious. Approximate amount of hidden data is 551 bytes.
# 4321.bmp is suspicious. Approximate amount of hidden data is 957 bytes.
# 3540.bmp is suspicious. Approximate amount of hidden data is 674 bytes.
# ...

# %%
# !cd StegExpose/ && java -jar StegExpose.jar ../dataset_lsb
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# test_2696.JPEG is suspicious. Approximate amount of hidden data is 220 bytes.
# test_3847.JPEG is suspicious. Approximate amount of hidden data is 381 bytes.
# test_3426.JPEG is suspicious. Approximate amount of hidden data is 672 bytes.
# test_274.JPEG is suspicious. Approximate amount of hidden data is 827 bytes.
# test_2387.JPEG is suspicious. Approximate amount of hidden data is 151 bytes.
# test_7896.JPEG is suspicious. Approximate amount of hidden data is 260 bytes.
# test_3081.JPEG is suspicious. Approximate amount of hidden data is 273 bytes.
# test_8141.JPEG is suspicious. Approximate amount of hidden data is 402 bytes.
# test_4088.JPEG is suspicious. Approximate amount of hidden data is 162 bytes.
# test_6015.JPEG is suspicious. Approximate amount of hidden data is 648 bytes.
# test_9917.JPEG is suspicious. Approximate amount of hidden data is 634 bytes.
# ...

# %%
# !cd StegExpose/ && java -jar StegExpose.jar ../dataset_ssb4
# Out:
# 3057.bmp is suspicious. Approximate amount of hidden data is 4109 bytes.
# 1827.bmp is suspicious. Approximate amount of hidden data is 4020 bytes.
# 2002.bmp is suspicious. Approximate amount of hidden data is 3032 bytes.
# 2889.bmp is suspicious. Approximate amount of hidden data is 3988 bytes.
# 4298.bmp is suspicious. Approximate amount of hidden data is 1886 bytes.
# 2717.bmp is suspicious. Approximate amount of hidden data is 3006 bytes.
# 162.bmp is suspicious. Approximate amount of hidden data is 2579 bytes.
# 1523.bmp is suspicious. Approximate amount of hidden data is 3857 bytes.
# 3827.bmp is suspicious. Approximate amount of hidden data is 3681 bytes.
# 458.bmp is suspicious. Approximate amount of hidden data is 3311 bytes.
# 4112.bmp is suspicious. Approximate amount of hidden data is 2831 bytes.
# 4816.bmp is suspicious. Approximate amount of hidden data is 1804 bytes.
# 3815.bmp is suspicious. Approximate amount of hidden data is 3977 bytes.
# ...

# %%
# !cd StegExpose/ && java -jar StegExpose.jar ../dataset_ssbn
# Out:
# 3057.bmp is suspicious. Approximate amount of hidden data is 3601 bytes.
# 2002.bmp is suspicious. Approximate amount of hidden data is 3064 bytes.
# 2889.bmp is suspicious. Approximate amount of hidden data is 2973 bytes.
# 4298.bmp is suspicious. Approximate amount of hidden data is 3102 bytes.
# 2717.bmp is suspicious. Approximate amount of hidden data is 1045 bytes.
# 162.bmp is suspicious. Approximate amount of hidden data is 1586 bytes.
# 1523.bmp is suspicious. Approximate amount of hidden data is 3377 bytes.
# 3827.bmp is suspicious. Approximate amount of hidden data is 2491 bytes.
# 458.bmp is suspicious. Approximate amount of hidden data is 3219 bytes.
# 4112.bmp is suspicious. Approximate amount of hidden data is 2193 bytes.
# 4816.bmp is suspicious. Approximate amount of hidden data is 3245 bytes.
# 3815.bmp is suspicious. Approximate amount of hidden data is 3435 bytes.
# 1394.bmp is suspicious. Approximate amount of hidden data is 3333 bytes.
# ...

# %% [markdown]
# <h3>Análisa o diretório de imagens que não contém esteganografia</h3>

# %%
# !cd StegExpose/ && java -jar StegExpose.jar ../dataset_original
# Out:
# 121.png is suspicious. Approximate amount of hidden data is 1172 bytes.
# 53.png is suspicious. Approximate amount of hidden data is 1992 bytes.
# 394.png is suspicious. Approximate amount of hidden data is 3399 bytes.
# 890.png is suspicious. Approximate amount of hidden data is 1651 bytes.
# 174.png is suspicious. Approximate amount of hidden data is 964 bytes.
# 913.png is suspicious. Approximate amount of hidden data is 989 bytes.
# 172.png is suspicious. Approximate amount of hidden data is 3008 bytes.
# 537.png is suspicious. Approximate amount of hidden data is 1100 bytes.
# 248.png is suspicious. Approximate amount of hidden data is 1706 bytes.
# 974.png is suspicious. Approximate amount of hidden data is 1166 bytes.
# 672.png is suspicious. Approximate amount of hidden data is 717 bytes.
# 59.png is suspicious. Approximate amount of hidden data is 3626 bytes.
# 38.png is suspicious. Approximate amount of hidden data is 2809 bytes.
# ...

# %% [markdown]
# <h3>Consulta a quantidade de arquivos nos diretórios análisados</h3>

# %%
len(os.listdir('dataset_original'))
# Out:
# 1000

# %%
len(os.listdir('dataset_encoder'))
# Out:
# 1000

# %%
len(os.listdir('dataset_dct'))
# Out:
# 4881

# %%
len(os.listdir('dataset_lsb_grayscale'))
# Out:
# 4881

# %%
len(os.listdir('dataset_lsb'))
# Out:
# 10000

# %%
len(os.listdir('dataset_ssb4'))
# Out:
# 4881

# %%
len(os.listdir('dataset_ssbn'))
# Out:
# 4881

# %% [markdown]
# <h3>Percentual de arquivos com esteganografia marcados com esteganografia</h3>

# %%
538/1000 # CNN
# Out:
# 0.538

# %%
3416/4881 # DCT
# Out:
# 0.6998565867650072

# %%
3128/4881 # LSB GRAYSCALE
# Out:
# 0.6408522843679574

# %%
5001/10000 # LSB
# Out:
# 0.5001

# %%
4843/4881 # SSB4
# Out:
# 0.9922147101003893

# %%
4796/4881 # SSBN
# Out:
# 0.9825855357508707

# %% [markdown]
# <h3>Percentual de arquivos sem esteganografia marcados com esteganografia</h3>

# %%
569/1000 # ORIGINAL
# Out:
# 0.569
